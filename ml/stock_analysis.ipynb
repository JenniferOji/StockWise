# %%
import numpy as np 
import pandas as pd # numpy wrapper 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import yfinance as yf

# %%
msft = yf.Ticker("MSFT")
# contains all info about the stock
msft_info = msft.info

# %%
# all the hisctorical market data
history = msft.history(period="max")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1986-03-13 00:00:00-05:00    0.054188    0.062156    0.054188    0.059500
# 1986-03-14 00:00:00-05:00    0.059500    0.062688    0.059500    0.061625
# 1986-03-17 00:00:00-05:00    0.061625    0.063219    0.061625    0.062688
# 1986-03-18 00:00:00-05:00    0.062688    0.063219    0.060562    0.061093
# 1986-03-19 00:00:00-05:00    0.061093    0.061625    0.059500    0.060031
# ...                               ...         ...         ...         ...
# 2025-11-04 00:00:00-05:00  511.760010  515.549988  507.839996  514.330017
# 2025-11-05 00:00:00-05:00  513.299988  514.830017  506.579987  507.160004
# 2025-11-06 00:00:00-05:00  505.660004  505.700012  495.809998  497.100006
# 2025-11-07 00:00:00-05:00  496.950012  499.380005  493.250000  496.820007
# 2025-11-10 00:00:00-05:00  500.035004  506.769989  498.799988  506.000000
#
#                                Volume  Dividends  Stock Splits
# Date
# 1986-03-13 00:00:00-05:00  1031788800        0.0           0.0
# 1986-03-14 00:00:00-05:00   308160000        0.0           0.0
# 1986-03-17 00:00:00-05:00   133171200        0.0           0.0
# 1986-03-18 00:00:00-05:00    67766400        0.0           0.0
# 1986-03-19 00:00:00-05:00    47894400        0.0           0.0
# ...                               ...        ...           ...
# 2025-11-04 00:00:00-05:00    20958700        0.0           0.0
# 2025-11-05 00:00:00-05:00    23024300        0.0           0.0
# 2025-11-06 00:00:00-05:00    27406500        0.0           0.0
# 2025-11-07 00:00:00-05:00    23980600        0.0           0.0
# 2025-11-10 00:00:00-05:00    25620294        0.0           0.0
#
# [9994 rows x 7 columns]
